# %% [markdown]
# # Sales of Honey in US Analysis
# #### By : Manan Verma

# %%
# Agenda - Work on US - Honey , case study

# %%
# sales of honey in diff. states of America

# %%
# Dataset link -> https://drive.google.com/file/d/1hgEjYd5-UsqaWrpF-8q5QH2Ph6BuWUet/view?usp=sharing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('US_honey_dataset (1) (1).csv',skipinitialspace=True)

# %%
df
# Out:
#       Unnamed: 0         state  colonies_number  yield_per_colony  production  \
# 0              0       Alabama            16000                58      928000
# 1              1       Arizona            52000                79     4108000
# 2              2      Arkansas            50000                60     3000000
# 3              3    California           420000                93    39060000
# 4              4      Colorado            45000                60     2700000
# ...          ...           ...              ...               ...         ...
# 1110        1110      Virginia             6000                40       79000
# 1111        1111    Washington            96000                32     1206000
# 1112        1112  WestVirginia             6000                43      136000
# 1113        1113     Wisconsin            42000                47      750000
# 1114        1114       Wyoming            38000                58      242000
#
# ...

# %%
df.head()  # By default it gives first 5 values
# Out:
#    Unnamed: 0       state  colonies_number  yield_per_colony  production  \
# 0           0     Alabama            16000                58      928000
# 1           1     Arizona            52000                79     4108000
# 2           2    Arkansas            50000                60     3000000
# 3           3  California           420000                93    39060000
# 4           4    Colorado            45000                60     2700000
#
#     stocks  average_price  value_of_production  year
# 0    28000           62.0               575000  1995
# 1   986000           68.0              2793000  1995
# 2   900000           64.0              1920000  1995
# 3  4687000           60.0             23436000  1995
# 4  1404000           68.0              1836000  1995

# %%
df.shape
# Out:
# (1115, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1115 entries, 0 to 1114
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           1115 non-null   int64
#  1   state                1115 non-null   object
#  2   colonies_number      1115 non-null   int64
#  3   yield_per_colony     1115 non-null   int64
#  4   production           1115 non-null   int64
#  5   stocks               1115 non-null   int64
#  6   average_price        1115 non-null   float64
#  7   value_of_production  1115 non-null   int64
#  8   year                 1115 non-null   int64
# dtypes: float64(1), int64(7), object(1)
# memory usage: 78.5+ KB

# %%
# When u have null values - drop it , fill it

# %%
# if u have , let's say 100 rows , out of those , in 50 rows , u have null value , fill it

# %%
# with what value should we fill - mean , median , mode
# It totally depends on the dataset , u are using
# when u are having outliers - median(this does not get affected by outliers)
# when u do not have  outliers - mean
# when u are having object dt(string values) - mode , Gender - male , female

# %%
1,2,3,4,5,6,7,8,500
# mean  - 400

# %%
# 1000000 rows , 100 values are null - drop it

# %%
# State- wise production ,barplot
plt.figure(figsize = (20,4))  # width , height
sns.barplot(x="state", y="productionhttps://drive.google.com/file/d/1hgEjYd5-UsqaWrpF-8q5QH2Ph6BuWUet/view?usp=sharing", data = df)
plt.title("State wise production")
plt.xlabel("State")
plt.ylabel("Production")
plt.xticks(rotation = 90) # it is used to change the orientation
plt.show()

# %%
# create a barplot , x- state , y- stocks

# %%
# Groupby  - Group the values based on some condition/parameter

# %%
# Top and Botton 5 states v/s  avg price, value_of_production

# %%
States_Production = df.groupby('state')["production"].sum().reset_index()

# %%
States_Production
# Out:
#             state  production
# 0         Alabama    14467000
# 1         Arizona    38844000
# 2        Arkansas    51846000
# 3      California   423876000
# 4        Colorado    32660000
# 5         Florida   280934000
# 6         Georgia    57426000
# 7          Hawaii    15420000
# 8           Idaho    87188000
# 9        Illinois     9864000
# 10        Indiana     9686000
# 11           Iowa    48607000
# 12         Kansas    14138000
# 13       Kentucky     3224000
# 14      Louisiana    60568000
# 15          Maine     4762000
# 16       Maryland     1975000
# 17       Michigan   101063000
# 18      Minnesota   176581000
# 19    Mississippi    21235000
# 20       Missouri    17904000
# 21        Montana   197173000
# 22       Nebraska    63655000
# 23         Nevada     7399000
# 24      NewJersey     6913000
# 25      NewMexico    10082000
# 26        NewYork    78444000
# 27  NorthCarolina     8909000
# 28    NorthDakota   513742000
# 29           Ohio    22485000
# ...

# %%
a= 10
a
# Out:
# 10

# %%
# i += 1
# i = i + 1

# %%
# Top and Botton 5 states v/s  production ,avg price, value_of_production

# %%
Top_5_States_Production = States_Production.sort_values(by = 'production', ascending=False).head(5)

# %%
Top_5_States_Production
# Out:
#           state  production
# 28  NorthDakota   513742000
# 3    California   423876000
# 34  SouthDakota   355726000
# 5       Florida   280934000
# 21      Montana   197173000
